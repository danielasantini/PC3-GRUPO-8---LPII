# %%
import requests
response=requests.get('https://api.escuelajs.co/api/v1/products')

data2=response.text

# %%
import json

info = json.loads(data2)
info
#print('número de usuarios:', len(info))
# Out:
# [{'id': 1,
#   'title': 'Intelligent Cotton Bike',
#   'price': 266,
#   'description': 'The automobile layout consists of a front-engine design, with transaxle-type transmissions mounted at the rear of the engine and four wheel drive',
#   'images': ['https://api.lorem.space/image/shoes?w=640&h=480&r=2776',
#    'https://api.lorem.space/image/shoes?w=640&h=480&r=4244',
#    'https://api.lorem.space/image/shoes?w=640&h=480&r=3089'],
#   'creationAt': '2023-01-11T00:40:07.000Z',
#   'updatedAt': '2023-01-11T00:40:07.000Z',
#   'category': {'id': 4,
#    'name': 'Shoes',
#    'image': 'https://api.lorem.space/image/shoes?w=640&h=480&r=1883',
#    'creationAt': '2023-01-11T00:40:07.000Z',
#    'updatedAt': '2023-01-11T00:40:07.000Z'}},
#  {'id': 2,
#   'title': 'Handcrafted Plastic Salad',
#   'price': 210,
#   'description': 'The Apollotech B340 is an affordable wireless mouse with reliable connectivity, 12 months battery life and modern design',
# ...

# %%
id=[]
titulos=[]
precios=[]
descripcion=[]
categoria=[]

for item in info:
  id.append(item['id']-1)
  titulos.append(item['title'])
  precios.append(item['price'])
  descripcion.append(item['description'])
  categoria.append(item['category']['name'])
  #print('Attribute', item['x'])

# %% [markdown]
# Convertir a tabla

# %%
import pandas as pd

Tabla = pd.DataFrame(zip(titulos,precios,descripcion,categoria),
                        columns=['Artículo','Precios','Descripcion','Categoria']
                        )
Tabla
# Out:
#                       Artículo  Precios  \
# 0      Intelligent Cotton Bike      266
# 1    Handcrafted Plastic Salad      210
# 2        Oriental Wooden Chips      692
# 3     Intelligent Cotton Shirt      768
# 4      Electronic Bronze Chair      334
# ..                         ...      ...
# 200                        200      200
# 201                        200      200
# 202         New Product Course     9999
# 203                       MAti      204
# 204         New Product Course     9999
#
#                                            Descripcion    Categoria
# 0    The automobile layout consists of a front-engi...        Shoes
# 1    The Apollotech B340 is an affordable wireless ...  Electronics
# 2    Carbonite web goalkeeper gloves are ergonomica...    Furniture
# 3    The Nagasaki Lander is the trademarked name of...       Others
# 4    Carbonite web goalkeeper gloves are ergonomica...  Electronics
# ..                                                 ...          ...
# ...

# %% [markdown]
# Algunos estadísticos

# %%
Tabla.describe()
# Out:
#            Precios
# count   205.000000
# mean    563.487805
# std     978.027074
# min       3.000000
# 25%     247.000000
# 50%     446.000000
# 75%     699.000000
# max    9999.000000

# %% [markdown]
# Variabilidad de precios

# %%
import matplotlib.pyplot as plt

plt.boxplot(precios,vert=True,patch_artist=True);

# %% [markdown]
# Dado que la muestra no es pequeña, es adecuado graficar el diagrama de cajas ya que los valores de la caja serían significativos.
#
# Con la gráfica podemos concluir:
#
# La mayoría de los precios cuestan entre 248.25 soles y 696.50 soles. Sin embargo, existe algunos que cuestan 3 soles y el máximo costo es de 997 soles.
#
# El valor central de los precios rondan los 441 soles.
#
# Finalmente, podemos afirmar también que no hay valores atípicos.

# %% [markdown]
# Categorias más compradas

# %%
def unique_values(lista):
    unicos = []
    for valor in lista:
      if valor not in unicos:
        unicos.append(valor)
    return unicos

# %%
Categorias = unique_values(categoria)
shoes,electronics,furniture,others,clothes=0,0,0,0,0

for i in categoria:
  if i == Categorias[0]:
    shoes+=1
  elif i == Categorias[1]:
    electronics+=1
  elif i == Categorias[2]:
    furniture+=1
  elif i == Categorias[3]:
    others+=1
  elif i == Categorias[4]:
    clothes+=1

cantidad = [shoes,electronics,furniture,others,clothes]
cantidad
# Out:
# [44, 49, 36, 38, 38]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:green', 'tab:blue', 'tab:red', 'tab:orange', 'tab:brown']

ax.bar(Categorias, cantidad, label=bar_labels, color=bar_colors)

ax.set_ylabel('cantidad')
ax.set_title('Categorias de productos')
ax.legend(title='Categorias')

plt.show()
